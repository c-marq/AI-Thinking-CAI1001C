# %% [markdown]
# # Non-Guided Project 11: Social-Media-Sentiment-Tracker
#
# **Name:** [Your Name Here]
# **Course:** CAI1001C - AI Thinking
#
# ---

# %%
# Import libraries
import pandas as pd
import numpy as np
