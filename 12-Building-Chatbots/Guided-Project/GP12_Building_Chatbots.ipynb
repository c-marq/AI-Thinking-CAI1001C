# %% [markdown]
# <a href="https://colab.research.google.com/github/c-marq/AI-Thinking-CAI1001C/blob/main/12-Building-Chatbots/Guided-Project/GP12_Building_Chatbots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GP12: Building Chatbots
# ### CAI1001C: Artificial Intelligence (AI) Thinking
# **Chapter 12 · Week 12 · Miami Dade College**
#
# ---
#
# **Guided Project — Reference Material (Not Graded)**
#
# In this guided project, you'll build a working chatbot from scratch in Python. You'll start with the simplest possible version (3 intents, one interaction) and progressively add intelligence: a response dictionary, random variation, a conversation loop, conversation logging, and smart fallback handling.
#
# By the end, you'll have a fully functional Student Services chatbot that recognizes 7 different intents, varies its responses, and tracks its own performance.
#
# **Keep this notebook** — it's your reference for the group lab and homework.

# %% [markdown]
# ## Learning Objectives
#
# By the end of this guided project, you will be able to:
#
# 1. **Build a rule-based chatbot** using `if/elif` keyword matching in Python
# 2. **Structure intents** using a response dictionary with keyword lists and multiple responses
# 3. **Add response variation** with `random.choice()` to make the chatbot feel more natural
# 4. **Implement a conversation loop** that keeps the chatbot running until the user exits
# 5. **Log and analyze conversations** to measure chatbot performance (intent counts, success rate)

# %%
# ============================================
# Run this cell first — imports
# ============================================
# No pip installs needed — we're using only built-in Python libraries!

import random

print("Setup complete! Ready to build your chatbot.")

# %% [markdown]
# ## A Note About Data
#
# Unlike previous GPs, there's no external dataset to load today. Our chatbot's "data" is the **intent-response dictionary** we'll define directly in code — the questions it can answer and the responses it can give. Think of it as coding Abuela Carmen's FAQ binder into Python.
#
# ---

# %% [markdown]
# ## Example 12.1: Your First Chatbot
#
# Let's start with the absolute simplest chatbot possible: **3 intents, keyword matching, one single interaction.** No loop, no dictionary — just `if/elif` and the `in` operator.
#
# The chatbot will handle three questions a Student Services desk gets constantly:
# - **Hours** — "When are you open?"
# - **Tutoring** — "Where can I get help?"
# - **Financial Aid** — "How do I apply for aid?"
#
# If the user asks something else, the bot gives a **fallback response** — the "Let me get the manager" of the chatbot world.

# %%
# ============================================
# Example 12.1: Your First Chatbot
# Purpose: Basic keyword matching with if/elif
# Prerequisites: None — just Python basics
# ============================================

# Step 1: Get the user's message and convert to lowercase
user_message = input("You: ").lower()

# Step 2: Check for keywords and respond
if "hours" in user_message or "open" in user_message:
    print("Bot: We're open Monday through Friday, 8am to 6pm, and Saturday 9am to 1pm!")
elif "tutoring" in user_message or "tutor" in user_message:
    print("Bot: Free tutoring is available in the Learning Center, Room 2201. No appointment needed!")
elif "financial" in user_message or "aid" in user_message:
    print("Bot: The Financial Aid office is in Room 1145. You can also apply online at studentaid.gov.")
else:
    print("Bot: I'm not sure how to help with that. Try asking about hours, tutoring, or financial aid.")

# Expected Output (if you type "what are your hours?"):
# You: what are your hours?
# Bot: We're open Monday through Friday, 8am to 6pm, and Saturday 9am to 1pm!

# Expected Output (if you type "tell me about the weather"):
# You: tell me about the weather
# Bot: I'm not sure how to help with that. Try asking about hours, tutoring, or financial aid.

# %% [markdown]
# ### What Just Happened
#
# You built a working chatbot in 12 lines of code. Here's the logic:
#
# 1. **`.lower()`** converts the user's input to lowercase so "HOURS", "Hours", and "hours" all match the same keyword
# 2. **`"hours" in user_message`** checks if the word "hours" appears *anywhere* in the message — it's substring matching, not exact matching
# 3. **`or`** lets us check multiple keywords for the same intent — someone might say "hours" or "open" and mean the same thing
# 4. **`else`** is the fallback — it catches everything that doesn't match any intent
#
# The bot handled one question and stopped. That's not much of a conversation. We'll fix that next.

# %% [markdown]
# ### ▶ Your Turn
#
# **Try these experiments** (re-run the cell above for each one):
#
# 1. Type `"what are your hours?"` — does it match the hours intent? ✅
# 2. Type `"WHAT ARE YOUR HOURS?"` in all caps — does it still work? Why?
# 3. Type `"tell me about the weather"` — what happens?
# 4. Now try: `"what are the hours for tutoring?"` — which intent fires? Why that one and not the other?
#
# **Challenge:** Add a 4th intent for **parking** before the `else`. Use keywords `"parking"` and `"permit"`. What response would you give?

# %%
# YOUR CODE HERE — Try adding a parking intent to Example 12.1
# Copy the code from Example 12.1 above and add a new elif branch

# %% [markdown]
# ---
#
# ## Example 12.2: A Smarter Chatbot
#
# Example 12.1 has three problems:
# 1. Each intent is a hardcoded `if/elif` branch — adding 10 more means 10 more branches
# 2. The response is the same every time — robotic and repetitive
# 3. The conversation ends after one exchange — not much of a "chat"
#
# We'll fix all three by introducing:
# - A **response dictionary** that stores intents as structured data
# - **`random.choice()`** to pick a different response each time
# - A **conversation loop** that keeps going until the user says "bye"

# %%
# ============================================
# Example 12.2: A Smarter Chatbot
# Purpose: Dictionary-based intents, random responses, conversation loop
# Prerequisites: Example 12.1 concepts
# ============================================

import random

# Step 1: Define intents with keyword lists and multiple responses
intents = {
    "hours": {
        "keywords": ["hours", "open", "close", "schedule"],
        "responses": [
            "We're open Monday–Friday, 8am–6pm, and Saturday 9am–1pm!",
            "Our hours are Mon–Fri 8am to 6pm. Saturdays we're open 9am to 1pm.",
            "You can visit us Monday through Friday, 8am–6pm. We also have Saturday hours: 9am–1pm."
        ]
    },
    "tutoring": {
        "keywords": ["tutoring", "tutor", "help", "study"],
        "responses": [
            "Free tutoring is available in the Learning Center, Room 2201. No appointment needed!",
            "Head to Room 2201 for free tutoring — walk-ins welcome!",
            "The Learning Center in Room 2201 offers free tutoring. Just show up!"
        ]
    },
    "financial_aid": {
        "keywords": ["financial", "aid", "scholarship", "fafsa"],
        "responses": [
            "The Financial Aid office is in Room 1145. Apply online at studentaid.gov!",
            "Visit Room 1145 for Financial Aid, or start your FAFSA at studentaid.gov.",
            "Need help paying for school? Room 1145 has your answers. Start at studentaid.gov!"
        ]
    },
    "registration": {
        "keywords": ["register", "enroll", "class", "sign up", "registration"],
        "responses": [
            "You can register for classes through MyMDC at my.mdc.edu.",
            "Head to my.mdc.edu to register! Your advisor can help you pick classes.",
            "Registration is online at my.mdc.edu. See your advisor if you need help choosing courses."
        ]
    },
    "greeting": {
        "keywords": ["hello", "hi", "hey", "good morning", "good afternoon"],
        "responses": [
            "Hello! Welcome to MDC Student Services. How can I help you today?",
            "Hey there! What can I help you with?",
            "Hi! I'm the Student Services Bot. Ask me about hours, tutoring, financial aid, or registration."
        ]
    }
}

# Step 2: Create a function to find the matching intent
def get_response(message):
    message = message.lower()
    for intent_name, intent_data in intents.items():
        for keyword in intent_data["keywords"]:
            if keyword in message:
                return random.choice(intent_data["responses"])
    return "I'm not sure how to help with that. Try asking about hours, tutoring, financial aid, or registration."

# Step 3: Run the conversation loop
print("Student Services Bot: Hi! Ask me anything. Type 'bye' to exit.\n")
while True:
    user_input = input("You: ")
    if user_input.lower() in ["bye", "quit", "exit"]:
        print("Bot: Goodbye! Good luck with your studies! 🎓")
        break
    response = get_response(user_input)
    print(f"Bot: {response}\n")

# Expected Output (sample conversation):
# Student Services Bot: Hi! Ask me anything. Type 'bye' to exit.
#
# You: hi
# Bot: Hey there! What can I help you with?
#
# You: when are you open?
# Bot: Our hours are Mon–Fri 8am to 6pm. Saturdays we're open 9am to 1pm.
#
# You: I need help with my fafsa
# Bot: Visit Room 1145 for Financial Aid, or start your FAFSA at studentaid.gov.
#
# You: what's the cafeteria menu?
# Bot: I'm not sure how to help with that. Try asking about hours, tutoring, financial aid, or registration.
#
# You: bye
# Bot: Goodbye! Good luck with your studies! 🎓

# %% [markdown]
# ### What Just Happened
#
# Three major upgrades:
#
# 1. **Response dictionary** — Instead of hardcoded `if/elif` branches, every intent is a dictionary entry with a name, keyword list, and response list. Adding a new intent means adding one new dictionary entry — the `get_response()` function doesn't change at all.
#
# 2. **`random.choice()`** — Each intent has 3 possible responses. The bot picks one randomly each time, so saying "hi" twice in a row might give you two different greetings. This small touch makes the bot feel less robotic.
#
# 3. **Conversation loop** — `while True` keeps the conversation going. The only exit is typing "bye", "quit", or "exit". This transforms the bot from a one-shot answer machine into something that feels like an actual conversation.
#
# **The `get_response()` function** is the engine. It takes any message, lowercases it, then loops through every intent checking every keyword. **First match wins** — this matters when a message contains keywords from multiple intents.

# %% [markdown]
# ### ▶ Your Turn
#
# **Try these experiments** (re-run Example 12.2):
#
# 1. Type `"hi"` three times in a row. Do you get different responses each time?
# 2. Type just `"help"` — which intent does it match? Is that the right one? (Hint: "help" is a keyword in the tutoring intent)
# 3. Type `"Can you help me with parking?"` — what happens? The bot matches "help" to tutoring, not parking. This is the **false match** problem with generic keywords.
#
# **Challenge:** Add a 6th intent for **parking** with these specs:
# - Keywords: `["parking", "park", "permit", "garage"]`
# - 3 response variations about parking permits and MyMDC

# %%
# YOUR CODE HERE — Add a parking intent to the intents dictionary
# Then re-run the full Example 12.2 code with your addition

# %% [markdown]
# ---
#
# ## Example 12.3: The Full Chatbot — Applied Walkthrough
#
# Now we build the production version. We'll add:
# - **7 intents** (greeting, hours, tutoring, financial aid, registration, parking, advising)
# - **Smart fallback** that lists available topics instead of a dead-end message
# - **Conversation log** that tracks every exchange with intent labels
# - **Performance statistics** — intent counts and success rate
#
# The first part is pre-built. Your job is to complete the conversation log and statistics section.

# %%
# ============================================
# Example 12.3: Student Services Bot — Full Version
# Purpose: Complete chatbot with logging and smart fallback
# Prerequisites: Examples 12.1 and 12.2
# ============================================

import random

# Step 1: Define comprehensive intents (PRE-BUILT — do not modify)
intents = {
    "greeting": {
        "keywords": ["hello", "hi", "hey", "good morning", "good afternoon", "what's up"],
        "responses": [
            "Hello! Welcome to MDC Student Services. How can I help you today?",
            "Hey there! What can I help you with?",
            "Hi! I'm the Student Services Bot. Ask me about hours, tutoring, financial aid, registration, parking, or advising."
        ]
    },
    "hours": {
        "keywords": ["hours", "open", "close", "schedule", "time"],
        "responses": [
            "We're open Monday–Friday, 8am–6pm, and Saturday 9am–1pm!",
            "Our hours are Mon–Fri 8am to 6pm. Saturdays we're open 9am to 1pm.",
            "You can visit us Monday through Friday, 8am–6pm. We also have Saturday hours: 9am–1pm."
        ]
    },
    "tutoring": {
        "keywords": ["tutoring", "tutor", "study", "learning center"],
        "responses": [
            "Free tutoring is available in the Learning Center, Room 2201. No appointment needed!",
            "Head to Room 2201 for free tutoring — walk-ins welcome!",
            "The Learning Center in Room 2201 offers free tutoring. Just show up!"
        ]
    },
    "financial_aid": {
        "keywords": ["financial", "aid", "scholarship", "fafsa", "pay"],
        "responses": [
            "The Financial Aid office is in Room 1145. Apply online at studentaid.gov!",
            "Visit Room 1145 for Financial Aid, or start your FAFSA at studentaid.gov.",
            "Need help paying for school? Room 1145 has your answers. Start at studentaid.gov!"
        ]
    },
    "registration": {
        "keywords": ["register", "enroll", "class", "sign up", "registration", "add", "drop"],
        "responses": [
            "You can register for classes through MyMDC at my.mdc.edu.",
            "Head to my.mdc.edu to register! Your advisor can help you pick classes.",
            "Registration is online at my.mdc.edu. See your advisor if you need help choosing courses."
        ]
    },
    "parking": {
        "keywords": ["parking", "park", "car", "garage", "permit"],
        "responses": [
            "Parking permits are available online at my.mdc.edu under 'Parking Services.'",
            "You'll need a parking permit — grab one online through your MyMDC portal.",
            "Parking info is at my.mdc.edu. Permits are required in all campus garages and lots."
        ]
    },
    "advising": {
        "keywords": ["advisor", "advising", "major", "degree", "transfer", "graduate"],
        "responses": [
            "Academic advising is in Room 1201. You can also book online through MyMDC.",
            "Need to talk about your major or transfer plans? Visit Advising in Room 1201.",
            "Your advisor can help with degree planning — book an appointment at my.mdc.edu."
        ]
    }
}

# Step 2: Improved response function with smart fallback (PRE-BUILT)
def get_response(message):
    message = message.lower()
    for intent_name, intent_data in intents.items():
        for keyword in intent_data["keywords"]:
            if keyword in message:
                return intent_name, random.choice(intent_data["responses"])

    # Smart fallback: list available topics
    available = list(intents.keys())
    available.remove("greeting")
    topic_list = ", ".join(available).replace("_", " ")
    return "unknown", f"I'm not sure about that one. I can help with: {topic_list}. What would you like to know?"

print("✅ Intents and get_response() loaded. Run the next cell to start the chatbot.")

# %%
# Step 3: Conversation loop with logging (PRE-BUILT)
# Use the 10-input test transcript:
#   1. "Hello!"
#   2. "What are your hours?"
#   3. "I need tutoring for math"
#   4. "How do I apply for financial aid?"
#   5. "I want to sign up for classes"
#   6. "Where do I park?"
#   7. "Who is my advisor?"
#   8. "What's the wifi password?"
#   9. "Can I get food on campus?"
#   10. "bye"

conversation_log = []
print("🤖 Student Services Bot")
print("-" * 40)
print("Bot: Hi! I'm the MDC Student Services Bot.")
print("     Ask me about hours, tutoring, financial aid,")
print("     registration, parking, or advising.")
print("     Type 'bye' to exit.\n")

while True:
    user_input = input("You: ")

    if user_input.lower().strip() in ["bye", "quit", "exit", "goodbye"]:
        farewell = "Goodbye! Good luck with your studies! 🎓"
        print(f"Bot: {farewell}")
        conversation_log.append((user_input, farewell, "exit"))
        break

    intent, response = get_response(user_input)
    print(f"Bot: {response}\n")
    conversation_log.append((user_input, response, intent))

print(f"\n✅ Conversation ended. {len(conversation_log)} exchanges logged.")

# %% [markdown]
# ### ▶ Your Turn: Build the Conversation Log Display
#
# Now it's your turn. The `conversation_log` list contains every exchange as a tuple: `(user_input, bot_response, intent_name)`. Write code to display it in a readable format.
#
# **Your code should:**
# 1. Print a header ("CONVERSATION LOG")
# 2. Print the total number of exchanges
# 3. Loop through `conversation_log` and print each exchange with a number, the user's message, the bot's response, and the detected intent

# %%
# YOUR CODE HERE — Display the conversation log
# Hint: Use enumerate(conversation_log, 1) to get numbered entries
# Each entry is a tuple: (user_msg, bot_msg, intent)

print("=" * 50)
print("CONVERSATION LOG")
print("=" * 50)
print(f"Total exchanges: {len(conversation_log)}")
print("-" * 50)

# Loop through conversation_log and print each exchange
# YOUR CODE HERE

# %% [markdown]
# ### ▶ Your Turn: Calculate Intent Statistics
#
# Now build the performance summary. Count how many times each intent was triggered and calculate the success rate (what percentage of messages were matched vs. hitting the fallback).
#
# **Your code should:**
# 1. Count occurrences of each intent (excluding "exit")
# 2. Print the intent summary
# 3. Calculate and print the success rate: `(matched / total) * 100`

# %%
# YOUR CODE HERE — Intent summary and success rate
# Hint: Create a dictionary to count intents
# An "unknown" intent means the fallback was triggered

intent_counts = {}
for _, _, intent in conversation_log:
    if intent != "exit":
        # YOUR CODE HERE — count each intent


# Print intent summary
print("Intent Summary:")
# YOUR CODE HERE — print each intent and its count


# Calculate success rate
unknown_count = intent_counts.get("unknown", 0)
total = len(conversation_log) - 1  # Exclude exit
# YOUR CODE HERE — calculate and print success rate

# %% [markdown]
# ### Expected Results
#
# If you used the 10-input test transcript, your conversation log should show:
#
# | # | Input | Intent |
# |---|-------|--------|
# | 1 | "Hello!" | greeting |
# | 2 | "What are your hours?" | hours |
# | 3 | "I need tutoring for math" | tutoring |
# | 4 | "How do I apply for financial aid?" | financial_aid |
# | 5 | "I want to sign up for classes" | registration |
# | 6 | "Where do I park?" | parking |
# | 7 | "Who is my advisor?" | advising |
# | 8 | "What's the wifi password?" | unknown ❌ |
# | 9 | "Can I get food on campus?" | unknown ❌ |
# | 10 | "bye" | exit |
#
# **Intent Summary:** 7 matched intents + 2 unknown = 9 non-exit messages
#
# **Success Rate:** 7/9 ≈ 78%
#
# Not bad for 7 intents! In production, chatbot teams use exactly this kind of data to identify the most common "unknown" queries and add new intents to cover them.

# %% [markdown]
# ### ▶ Your Turn: Try to Break the Bot
#
# Re-run the conversation loop (Step 3 cell) and try these edge cases:
#
# 1. **Typo test:** Type `"finacial ade"` — does the bot recognize financial aid with a typo?
# 2. **Multi-intent:** Type `"I need to register for classes and find out about parking"` — which intent wins?
# 3. **Keyword priority:** Type `"what are the hours for tutoring?"` — does it respond about hours or tutoring?
# 4. **Empty input:** Just press Enter without typing anything — what happens?
# 5. **Your own curveballs:** Try 3 messages you think will stump the bot. What patterns cause failures?
#
# **After testing, answer these questions in the next cell:**

# %%
# YOUR OBSERVATIONS HERE (use comments or print statements)
# 1. Did the typo test work? Why or why not?
#
# 2. For the multi-intent test, which intent fired? Why?
#
# 3. For the keyword priority test, what happened?
#
# 4. What were your 3 curveball messages and what happened?
#
# 5. What's the most common reason the bot fails?
#

# %% [markdown]
# ---
#
# ## Summary
#
# Today you built a working chatbot in three progressive steps:
#
# | Version | What It Does | Lines of Code |
# |---------|-------------|:---:|
# | **Example 12.1** | 3 intents, if/elif, single interaction | ~12 |
# | **Example 12.2** | 5 intents, dictionary, random.choice(), conversation loop | ~35 |
# | **Example 12.3** | 7 intents, smart fallback, conversation log, success rate | ~65 |
#
# The core concepts — **intent recognition, response generation, fallback handling, and conversation flow** — are the same in every chatbot, from your 65-line Python script to ChatGPT.
#
# ### What's Next
#
# **Group Lab:** You'll use Google AI Studio to design a chatbot persona using system prompts — a completely different approach to building chatbot behavior. Instead of coding keywords and responses, you'll write natural language instructions that tell an AI how to behave.
#
# **Next Week (Chapter 13):** This was your last coding chapter. From here on, the focus shifts from *building* AI to thinking critically about how it's deployed, governed, and shaped — including by you.
