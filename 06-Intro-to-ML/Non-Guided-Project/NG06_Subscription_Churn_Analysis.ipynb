# %% [markdown]
# <a href="https://colab.research.google.com/github/c-marq/AI-Thinking-CAI1001C/blob/main/06-Intro-to-ML/Non-Guided-Project/NG06_Subscription_Churn_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NG06: Subscription Churn Analysis 📊
#
# ## CAI1001C: Artificial Intelligence Thinking | Miami Dade College
#
# **Type:** Non-Guided Project — Graded Assignment
#
# ---
#
# ### Overview
#
# A streaming service is losing subscribers and wants to understand why. You've been given a dataset of 150 customers with information about their subscription and whether they canceled (churned). Your job: **use the ML workflow from class to predict churn and identify what drives it.**
#
# This project follows the same workflow you practiced in GP06 — load, explore, visualize, train, evaluate, interpret — but with a new dataset and context.
#
# ### Instructions
#
# - Complete **all 5 tasks** below
# - Write your code where you see `# YOUR CODE HERE` comments
# - Write your interpretations in the markdown cells provided
# - Run all cells top-to-bottom before submitting to make sure everything works
# - **Experienced students:** You may substitute your own dataset (must have at least 100 rows, 4+ numeric features, and a binary label). If you do, note this in Task 1.
#
# ### Grading Criteria
#
# | Component | Points |
# |-----------|--------|
# | Task 1: Load & Explore | 15 |
# | Task 2: Visualize | 20 |
# | Task 3: Features & Label | 10 |
# | Task 4: Train & Evaluate | 25 |
# | Task 5: Interpret | 20 |
# | Code runs without errors | 10 |
# | **Total** | **100** |
# | Bonus Challenge | +10 |
#
# ---

# %% [markdown]
# ## ⚙️ Setup
#
# Run this cell first. Do not modify it.

# %%
# === Setup: Run this cell first ===
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

plt.style.use('seaborn-v0_8-whitegrid')
print("✅ Setup complete!")

# %% [markdown]
# ## 📁 Load the Dataset
#
# Run this cell to load the subscription churn dataset. The dataset has 150 customers with 5 columns:
#
# | Column | Description |
# |--------|-------------|
# | `months_subscribed` | How long they've been a customer |
# | `monthly_charges` | What they pay per month ($) |
# | `support_tickets` | Number of support tickets filed |
# | `usage_hours` | Monthly usage in hours |
# | `churned` | Whether they canceled (1 = yes, 0 = no) |

# %%
# Load the dataset — do not modify this cell
url = "https://raw.githubusercontent.com/c-marq/AI-Thinking-CAI1001C/refs/heads/main/06-Intro-to-ML/Datasets/subscription_churn.csv"
df = pd.read_csv(url)
print(f"✅ Dataset loaded: {df.shape[0]} rows, {df.shape[1]} columns")
df.head()

# %% [markdown]
# ---
#
# ## Task 1: Load & Explore (15 points)
#
# Explore the dataset to understand what you're working with. Complete the code below to:
# 1. Print the shape of the dataset
# 2. Check data types
# 3. Check for missing values
# 4. Get basic statistics with `.describe()`
# 5. Print the churn distribution (how many churned vs. stayed)

# %%
# Task 1: Explore the dataset

# 1. Print the shape
print("Dataset shape:", df.shape)

# 2. Check data types
# YOUR CODE HERE


# 3. Check for missing values
# YOUR CODE HERE


# 4. Basic statistics
# YOUR CODE HERE


# 5. Churn distribution — how many customers churned vs. stayed?
# YOUR CODE HERE

# %% [markdown]
# **Task 1 Interpretation:** Write 2-3 sentences about what you found. How many customers churned? Are there any missing values? What do the basic statistics tell you?
#
# *Your answer:*

# %% [markdown]
# ---
#
# ## Task 2: Visualize (20 points)
#
# Create **at least 2 visualizations** that show the relationship between features and churn. Your charts should help you understand which features might predict churn.
#
# **Suggestions** (pick at least 2):
# - Scatter plot of `monthly_charges` vs. `usage_hours`, colored by `churned`
# - Histogram of `support_tickets` split by churn status
# - Box plots comparing each feature for churned vs. not-churned customers
#
# **Requirements:**
# - Each chart must have a title, axis labels, and a legend (if using color)
# - Use skills from Chapter 5 — `plt.subplots()`, color mapping, labels

# %%
# Task 2, Visualization 1
# Hint: You can use the same approach from GP06 Example 3

# YOUR CODE HERE

plt.show()

# %%
# Task 2, Visualization 2

# YOUR CODE HERE

plt.show()

# %% [markdown]
# **Task 2 Interpretation:** For each visualization, write 2-3 sentences describing what patterns you see. Which features seem to differ between churned and non-churned customers?
#
# *Visualization 1:*
#
#
# *Visualization 2:*

# %% [markdown]
# ---
#
# ## Task 3: Define Features & Label (10 points)
#
# Set up your features (X) and label (y) for the model.
#
# - **Features**: Use all four numeric columns (`months_subscribed`, `monthly_charges`, `support_tickets`, `usage_hours`)
# - **Label**: `churned`

# %%
# Task 3: Define features and label

# Define your feature columns as a list
features = # YOUR CODE HERE

# Create X (features) and y (label)
X = # YOUR CODE HERE
y = # YOUR CODE HERE

print(f"Features: {features}")
print(f"X shape: {X.shape}")
print(f"y shape: {y.shape}")
print(f"\nChurn rate: {y.mean():.1%}")

# %% [markdown]
# ---
#
# ## Task 4: Split, Train & Evaluate (25 points)
#
# Follow the ML workflow:
# 1. Split data into 80% training / 20% testing (use `random_state=42`)
# 2. Create and train a `LinearRegression` model
# 3. Print training and testing R² scores
# 4. Print the feature coefficients

# %%
# Task 4: Split, train, evaluate

# 1. Train/test split
# YOUR CODE HERE


# Print set sizes
print(f"Training samples: {len(X_train)}")
print(f"Testing samples:  {len(X_test)}")

# 2. Create and train the model
# YOUR CODE HERE


# 3. Evaluate — print R² scores for both sets
# YOUR CODE HERE


# 4. Print feature coefficients
# YOUR CODE HERE

# %% [markdown]
# **Task 4 Interpretation:** Write 2-3 sentences about your results. Are the training and testing scores close? What does that tell you about overfitting? Which feature has the largest coefficient?
#
# *Your answer:*

# %% [markdown]
# ---
#
# ## Task 5: Interpret & Predict (20 points)
#
# Use your trained model to make predictions and draw conclusions.
#
# 1. Create two fictional customer profiles and predict whether each will churn
# 2. Choose one customer who is "likely to churn" and one who is "likely to stay"
# 3. Explain why the model made each prediction based on the coefficients you found

# %%
# Task 5: Predict for two customer profiles

# Customer A — someone you think will STAY
customer_a = pd.DataFrame({
    'months_subscribed': [___],    # Fill in a value
    'monthly_charges': [___],      # Fill in a value
    'support_tickets': [___],      # Fill in a value
    'usage_hours': [___]           # Fill in a value
})

# Customer B — someone you think will CHURN
customer_b = pd.DataFrame({
    'months_subscribed': [___],    # Fill in a value
    'monthly_charges': [___],      # Fill in a value
    'support_tickets': [___],      # Fill in a value
    'usage_hours': [___]           # Fill in a value
})

# Make predictions
pred_a = model.predict(customer_a)[0]
pred_b = model.predict(customer_b)[0]

print("Customer A (expected: stay)")
print(f"  Prediction: {pred_a:.3f} → {'Likely to churn ⚠️' if pred_a > 0.5 else 'Likely to stay ✅'}")

print("\nCustomer B (expected: churn)")
print(f"  Prediction: {pred_b:.3f} → {'Likely to churn ⚠️' if pred_b > 0.5 else 'Likely to stay ✅'}")

# %% [markdown]
# **Task 5 Interpretation:** Write 3-4 sentences explaining:
# 1. What values did you choose for each customer and why?
# 2. Did the model's predictions match your expectations?
# 3. Based on the coefficients, which feature had the biggest impact on the predictions?
#
# *Your answer:*

# %% [markdown]
# ---
#
# ## 🌟 Bonus Challenge (+10 points) — Optional
#
# **Question:** Which feature has the biggest impact on churn predictions?
#
# To find out, remove features **one at a time**, retrain the model each time, and compare the testing R² scores. The feature whose removal hurts the score the most is the most important.
#
# | Removed Feature | Testing R² | Change from Full Model |
# |----------------|------------|----------------------|
# | None (full model) | ___ | — |
# | months_subscribed | ___ | ___ |
# | monthly_charges | ___ | ___ |
# | support_tickets | ___ | ___ |
# | usage_hours | ___ | ___ |
#
# After filling in the table, write 3-4 sentences:
# - Which feature is most important? Which is least important?
# - Does this make **business sense**? Why would that feature matter most for customer churn?

# %%
# BONUS: Remove one feature at a time and compare scores

all_features = ['months_subscribed', 'monthly_charges', 'support_tickets', 'usage_hours']

# YOUR CODE HERE
# Hint: Use a for loop. In each iteration:
#   1. Create a new feature list without one feature
#   2. Split, train, and evaluate
#   3. Print the testing R² score

# %% [markdown]
# **Bonus Interpretation:** Which feature is most important? Which is least important? Explain why this makes business sense.
#
# *Your answer:*

# %% [markdown]
# ---
#
# ## 📤 Submission Instructions
#
# 1. **Run all cells** top-to-bottom one final time (Runtime → Run all)
# 2. Make sure all outputs are visible and there are no errors
# 3. Make sure all interpretation cells are filled in
# 4. **Save** your notebook (File → Save)
# 5. **Download** as .ipynb (File → Download → Download .ipynb)
# 6. **Submit** through the course portal
#
# ### Before You Submit Checklist
# - [ ] All 5 tasks completed
# - [ ] All interpretation cells have 2-3 sentences each
# - [ ] Code runs without errors from top to bottom
# - [ ] Charts have titles and axis labels
# - [ ] Bonus challenge completed (optional)
#
# ---
# *This project is based on Chapter 6: Introduction to Machine Learning. Refer to your GP06 notebook and Chapter 6 reading for help.*
